# %% [markdown]
# # Pipeline Analysis Notebook
# Use this notebook for inspection and visualization only.
# Execution pipeline remains script/CLI-first.

# %%
from pathlib import Path
import json
import pandas as pd

base = Path('.')
print('Workspace:', base.resolve())
# Out:
# Running cells with '.venv (3.13.7) (Python 3.13.7)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/cherr/Downloads/DATASET-DTM/.venv/Scripts/python.exe -m pip install ipykernel -U --force-reinstall'

# %%
summary_path = Path('outputs/run_summary.txt')
print(summary_path.read_text(encoding='utf-8'))

# %%
metrics_path = Path('outputs/ml/metrics.json')
metrics = json.loads(metrics_path.read_text(encoding='utf-8'))
metrics

# %%
pred = pd.read_csv('outputs/ml/predictions.csv')
pred.head(), pred['risk_probability'].describe()

# %%
opt_summary = json.loads(Path('outputs/optimization/optimization_summary.json').read_text(encoding='utf-8'))
opt_summary
